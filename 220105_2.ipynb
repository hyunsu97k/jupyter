# %%
! pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.1
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome('driver/chromedriver')

driver.get('https://nid.naver.com/nidlogin.login')

elem_login = driver.find_element_by_id("id")
elem_login.clear()
elem_login.send_keys('kanghs1997')

elem_login = driver.find_element_by_id("pw")
elem_login.clear()
elem_login.send_keys('@rkdgustn8106')

xpath = '//*[@id="log.login"]' 

driver.find_element_by_xpath(xpath).click()
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/1816720438.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('driver/chromedriver')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/1816720438.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id("id")
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/1816720438.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem_login = driver.find_element_by_id("pw")
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/1816720438.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath(xpath).click()

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('driver/chromedriver')

driver.get('https://www.google.com')

search_box = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input")

search_box.send_keys('bts')
search_box.send_keys(Keys.RETURN)

# search = "/html/body/div[1]/div[3]/form/div[1]/div[1]/div[3]/center/input[1]"

# driver.find_element_by_xpath(search).click()
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/2356950434.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('driver/chromedriver')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/2356950434.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_box = driver.find_element_by_xpath("/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep

options = webdriver.ChromeOptions()
options.add_argument('window-size=1920,1080')

driver = webdriver.Chrome('driver/chromedriver', options=options)
driver.implicitly_wait(5)

driver.get(url='https://www.google.com/')

search_box = driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input')

search_box.send_keys('BTS')
search_box.send_keys(Keys.RETURN)

elements = driver.find_elements_by_xpath('//*[@id="rcnt"]')  #//*[@id="rcnt"]


for element in elements:
    print('lll{}'.format(element.text))
    print(element.text, file=open('bts.txt', 'w', encoding='utf-8'))

sleep(3)
#driver.close()
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/288705435.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('driver/chromedriver', options=options)
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/288705435.py:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_box = driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div[2]/div[2]/input')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_7828/288705435.py:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elements = driver.find_elements_by_xpath('//*[@id="rcnt"]')  #//*[@id="rcnt"]
# lll검색결과
# 동영상
# 미리보기
# 4:13
# BTS (방탄소년단) '작은 것들을 위한 시 (Boy With Luv) (feat ...
# YouTube · HYBE LABELS
# 2019. 4. 12.
# 미리보기
# 3:03
# BTS (방탄소년단) 'Butter' Official MV
# YouTube · HYBE LABELS
# 2021. 5. 21.
# 미리보기
# 4:16
# ...
